# %% [markdown]
# ![logo_MeIA.png](data:image/png;base64,...)

# %% [markdown]
# ---
# <center>
#
# 💻 **INTELIGENCIA ARTIFICIAL - LIDeSIA -FCEFyN - UNC**
#
# </center>
#
#
# ---

# %% [markdown]
# **Autor**: Equipo de la cátedra
#
# Directora:    Dra. Inga. Laura Diaz Dávila.
# ###![logoUNC_2.png](data:image/png;base64,...)

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.relplot(x='total_bill', y='tip', data=df);

# %%
sns.set(style="whitegrid")

# %%
sns.relplot(x='total_bill', y='tip', kind="scatter", data=df);

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=df);

# %%
sns.relplot(x='total_bill', y='tip', hue="smoker", style='smoker', data=df);

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='sex', data=df);

# %%
sns.relplot(x='total_bill', y='tip', hue='size', data=df);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", col="sex", data=df);

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-655c6f19-da41-42b8-89fa-f7e4faf7ce40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-655c6f19-da41-42b8-89fa-f7e4faf7ce40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv("/content/weather_IA.csv")

# %%
sns.relplot(x='MaxTemp', y="Evaporation", kind='line', data=df1)

# %%
sns.relplot(x='MaxTemp', y='Evaporation', kind='line', ci=None, data=df1)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.relplot(x='MaxTemp', y='Evaporation', hue='RainToday', kind='line', data=df1)

# %%
sns.catplot(x="day", y="tip", data=df);

# %%
sns.catplot(x='day',y='tip', jitter=False, data=df);

# %%
df[df.day=="Sun"].describe()
# Out:
#        total_bill        tip       size
# count   76.000000  76.000000  76.000000
# mean    21.410000   3.255132   2.842105
# std      8.832122   1.234880   1.007341
# min      7.250000   1.010000   2.000000
# 25%     14.987500   2.037500   2.000000
# 50%     19.630000   3.150000   2.000000
# 75%     25.597500   4.000000   4.000000
# max     48.170000   6.500000   6.000000

# %%
sns.catplot(x='day',y='tip', kind="swarm", data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', hue='sex', kind='swarm', data=df);
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="day", y="tip", kind="box", data=df);

# %%
sns.catplot(x='day', y='tip', kind='box', hue='sex', data=df);

# %%
df[df.day=="Sat"].describe()
# Out:
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    20.441379   2.993103   2.517241
# std      9.480419   1.631014   0.819275
# min      3.070000   1.000000   1.000000
# 25%     13.905000   2.000000   2.000000
# 50%     18.240000   2.750000   2.000000
# 75%     24.740000   3.370000   3.000000
# max     50.810000  10.000000   5.000000

# %%
sns.catplot(x='day', y='total_bill', hue='sex', kind='box',  data=df);

# %%
sns.catplot(x='day', y='total_bill', col='sex', kind='box',  data=df);

# %%
sns.displot(x='total_bill', data=df)

# %%
sns.displot(x='total_bill', col='smoker', data=df);

# %%
sns.displot(x='total_bill', hue='smoker', element='step', data=df);

# %%
sns.displot(x='total_bill', hue='smoker',col='sex', data=df);
